# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
## Importing Data set ords_prods_merge
df_ords_prods_merge = pd.read_pickle(r'/Users/javieraquezada/Desktop/05-2025 Instacart Basket Analysis/02 Data/Prepared Data/ords_prods_merge_new_variables.pkl')

# %%
##Creating Path
path = r'/Users/javieraquezada/Desktop/05-2025 Instacart Basket Analysis'

# %%
## Creating a subset dataframe of the first one million rows to avoid potential issues of processing power
df_subset_ords_prods_merge = df_ords_prods_merge[:1000000]

# %%
## Consistency Checks 
df_subset_ords_prods_merge.head()
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 0             0   2539329        1             1                   2
# 1             0   2539329        1             1                   2
# 2             0   2539329        1             1                   2
# 3             0   2539329        1             1                   2
# 4             0   2539329        1             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered  ... Unnamed: 0_y                             product_name  \
# ...

# %%
df_subset_ords_prods_merge.shape
# Out:
# (1000000, 21)

# %%
##Checking the values in the new column
df_subset_ords_prods_merge['price_range_loc'].value_counts(dropna=False)
# Out:
# price_range_loc
# Mid-range product     672525
# Low-range product     314109
# High-range product     12413
# NaN                      953
# Name: count, dtype: int64

# %%
## It shouldnt be any High range price range. So, Cheking for anomalies
df_subset['prices'].describe()
# Out:
# count    999047.000000
# mean         11.400000
# std         426.197447
# min           1.000000
# 25%           4.200000
# 50%           7.400000
# 75%          11.300000
# max       99999.000000
# Name: prices, dtype: float64

# %%
## Due to maximun shows a real high value seamly out of context...
##Checking for mistakes due to the course shows we shouldnt have "high range" values
df_subset_ords_prods_merge['prices'].max()
# Out:
# 99999.0

# %%
## Checking  and counting weird values...
df_subset_ords_prods_merge[df_subset_ords_prods_merge['prices'] > 100].shape[0]
# Out:
# 157

# %%
## 0.02% of the dataset. Checking weird values
df_subset_ords_prods_merge[df_subset_ords_prods_merge['prices'] > 100]['prices'].unique()
# Out:
# array([14900., 99999.])

# %%
## There is only 2 tipes of weird values which confirms, that might be a mistake ..
##Creating a new filtered data frame do get rid of these values.
df_ords_prods = df_subset_ords_prods_merge[df_subset_ords_prods_merge['prices'] <= 15]

# %%
##Checking the values in the new column after filtering
df_ords_prods['price_range_loc'].value_counts(dropna=False)
# Out:
# price_range_loc
# Mid-range product    672525
# Low-range product    314109
# Name: count, dtype: int64

# %%
## Cheking the most expensive product withing the clean subset
df_ords_prods['prices'].max()
# Out:
# 15.0

# %%
## Ready to Work.

# %%
## GROUPING with Pandas
df_ords_prods.groupby('product_name')

# %%
## Aggregating Data with agg()
df_ords_prods.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              14.792915
# 2.0              17.091743
# 3.0              17.919589
# 4.0              17.891973
# 5.0              15.214270
# 6.0              15.382228
# 7.0              17.699986
# 8.0              16.485269
# 9.0              15.965921
# 10.0             20.091818
# 11.0             16.485395
# 12.0             16.019741
# 13.0             16.485946
# 14.0             17.523474
# 15.0             15.690354
# 16.0             18.020350
# 17.0             16.155822
# 18.0             19.606536
# 19.0             17.630236
# 20.0             17.138204
# 21.0             21.996844

# %%
df_ords_prods.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1.0     14.792915
# 2.0     17.091743
# 3.0     17.919589
# 4.0     17.891973
# 5.0     15.214270
# 6.0     15.382228
# 7.0     17.699986
# 8.0     16.485269
# 9.0     15.965921
# 10.0    20.091818
# 11.0    16.485395
# 12.0    16.019741
# 13.0    16.485946
# 14.0    17.523474
# 15.0    15.690354
# 16.0    18.020350
# 17.0    16.155822
# 18.0    19.606536
# 19.0    17.630236
# 20.0    17.138204
# 21.0    21.996844
# Name: order_number, dtype: float64

# %%
df_ords_prods.groupby('department_id').order_number.mean()
# Out:
# department_id
# 1.0     14.792915
# 2.0     17.091743
# 3.0     17.919589
# 4.0     17.891973
# 5.0     15.214270
# 6.0     15.382228
# 7.0     17.699986
# 8.0     16.485269
# 9.0     15.965921
# 10.0    20.091818
# 11.0    16.485395
# 12.0    16.019741
# 13.0    16.485946
# 14.0    17.523474
# 15.0    15.690354
# 16.0    18.020350
# 17.0    16.155822
# 18.0    19.606536
# 19.0    17.630236
# 20.0    17.138204
# 21.0    21.996844
# Name: order_number, dtype: float64

# %%
df_ords_prods.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1.0              14.792915   1  99
# 2.0              17.091743   1  98
# 3.0              17.919589   1  99
# 4.0              17.891973   1  99
# 5.0              15.214270   1  99
# 6.0              15.382228   1  99
# 7.0              17.699986   1  99
# 8.0              16.485269   1  91
# 9.0              15.965921   1  99
# 10.0             20.091818   1  99
# 11.0             16.485395   1  99
# 12.0             16.019741   1  99
# 13.0             16.485946   1  99
# 14.0             17.523474   1  99
# 15.0             15.690354   1  99
# 16.0             18.020350   1  99
# 17.0             16.155822   1  99
# 18.0             19.606536   1  99
# 19.0             17.630236   1  99
# 20.0             17.138204   1  99
# 21.0             21.996844   1  97

# %%
## Agreggating data with transform()
##Creating new flag, establishing flag criteria.

# %%
## Splitting the data into groups based on user_id.
## Applying the transform() function on the order_number columnn to generate the maximum orders for each user.
##Create a new column,"max_order" into which you'll place the results of your aggregation.
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/n5/lt6zjw5j12s3tv1t42m14nqh0000gn/T/ipykernel_6854/3336747325.py:4: FutureWarning: The provided callable <function max at 0x104bf25c0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_prods_merge.head(15)
# Out:
#     Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 0              0   2539329        1             1                   2
# 1              0   2539329        1             1                   2
# 2              0   2539329        1             1                   2
# 3              0   2539329        1             1                   2
# 4              0   2539329        1             1                   2
# 5              1   2398795        1             2                   3
# 6              1   2398795        1             2                   3
# 7              1   2398795        1             2                   3
# 8              1   2398795        1             2                   3
# 9              1   2398795        1             2                   3
# 10             1   2398795        1             2                   3
# 11             2    473747        1             3                   3
# ...

# %%
##Printing the head of the dataframe
df_ords_prods_merge.head(100)
# Out:
#     Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 0              0   2539329        1             1                   2
# 1              0   2539329        1             1                   2
# 2              0   2539329        1             1                   2
# 3              0   2539329        1             1                   2
# 4              0   2539329        1             1                   2
# 5              1   2398795        1             2                   3
# 6              1   2398795        1             2                   3
# 7              1   2398795        1             2                   3
# 8              1   2398795        1             2                   3
# 9              1   2398795        1             2                   3
# 10             1   2398795        1             2                   3
# 11             2    473747        1             3                   3
# ...

# %%
## for checking all 100 rows
pd.options.display.max_rows = None

# %%
df_ords_prods_merge.head(100)
# Out:
#     Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 0              0   2539329        1             1                   2
# 1              0   2539329        1             1                   2
# 2              0   2539329        1             1                   2
# 3              0   2539329        1             1                   2
# 4              0   2539329        1             1                   2
# 5              1   2398795        1             2                   3
# 6              1   2398795        1             2                   3
# 7              1   2398795        1             2                   3
# 8              1   2398795        1             2                   3
# 9              1   2398795        1             2                   3
# 10             1   2398795        1             2                   3
# 11             2    473747        1             3                   3
# ...

# %%
## Deriving Columns with loc()
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
## printing
df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15891507
# Loyal customer      10294027
# New customer         6249525
# Name: count, dtype: int64

# %%
df_ords_prods_merge['loyalty_flag'].head(100)
# Out:
# 0         New customer
# 1         New customer
# 2         New customer
# 3         New customer
# 4         New customer
# 5         New customer
# 6         New customer
# 7         New customer
# 8         New customer
# 9         New customer
# 10        New customer
# 11        New customer
# 12        New customer
# 13        New customer
# 14        New customer
# 15        New customer
# 16        New customer
# 17        New customer
# 18        New customer
# 19        New customer
# 20        New customer
# 21        New customer
# 22        New customer
# 23        New customer
# 24        New customer
# 25        New customer
# 26        New customer
# 27        New customer
# 28        New customer
# 29        New customer
# 30        New customer
# 31        New customer
# 32        New customer
# 33        New customer
# 34        New customer
# 35        New customer
# 36        New customer
# 37        New customer
# 38        New customer
# 39        New customer
# ...

# %%
df_ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# ...

# %%
## Exporting DataFrame
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge_new_variables2.pkl'))
