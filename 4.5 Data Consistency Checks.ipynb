# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
##Import Data
df_ords = pd.read_csv(r'/Users/javieraquezada/Desktop/05-2025 Instacart Basket Analysis/02 Data/Prepared Data/orders_wrangled.csv',index_col = False)

# %%
##Creating Path
path = r'/Users/javieraquezada/Desktop/05-2025 Instacart Basket Analysis'

# %%
path
# Out:
# '/Users/javieraquezada/Desktop/05-2025 Instacart Basket Analysis'

# %%
##Importing products.csv from Original Data
df_prods = pd.read_csv(os.path.join(path,'02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
###Consistency Check : Returning descriptive statistics fot the numeric values in the dataframe
df_prods.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %%
##Importing orders_wrangled.csv from Prepared Data
df_ords = pd.read_csv(os.path.join(path,'02 Data', 'Prepared Data', 'orders_wrangled.csv'), index_col = False)

# %%
### Consistency Check : Returning descriptive statistics fot the numeric values in the dataframe
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_week  order_hour_of_day  days_since_prior_order
# count        3.421083e+06       3.421083e+06            3.214874e+06
# mean         2.776219e+00       1.345202e+01            1.111484e+01
# std          2.046829e+00       4.226088e+00            9.206737e+00
# min          0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %%
#Create a dataframe called df_test.
df_test=pd.DataFrame()
print(df_test)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Create a mixed type column( creates a new columnn mix withing df_test and fills it with numeric, string, and booleand values.)
df_test['mix'] = ['a','b',1,True]
print(df_test['mix'][2])
# Out:
# 1

# %%
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
## Cheking for mixed types// Structure named for_loop ( for this elements, do this), and the loop describes
##how the structure works. Here, the for-loop is looping through each column in the dataframe and executing 
##the same block of code each time.
for col in df_test.columns.tolist():
    weird = (df_test[[col]].map(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_test[weird])> 0:
        print(col)
# Out:
# mix

# %%
## fixing mixed-type columns withing the dataframe.
df_test['mix']= df_test['mix'].astype('str')

# %%
print(df_test)
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
## MISSING VALUES ( due to data corruption or not recorded)

# %%
## the isnull function is designed to find missing observations here refering to entries in the dataframe. (like excel cells)
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
## Creating a dataframe to see the 16 missing values, containing only those values within the product name column that
##meet the condition
df_nan = df_prods[df_prods['product_name'].isnull() == True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
## Adressing missing values. 3 ways.
### 1 Create a new variable that acts like a flag based on the missing value
## 2 Imput the value with the mean or median of the column ( if the variable is numeric)
## 3 Remove or filter out the missing data.

# %%
df_prods.shape
# Out:
# (49693, 5)

# %%
##Creating new dataframe due the missing values are product names.
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]
## False because now we want non-missing values in the new dataframe 
## new dataframe should have exactly 16 less rows than the original dataframe.

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
## another way would droppig missing values. Specified as False to only get a view of the changed dataframe
df_prods.dropna(subset = ['product_name'], inplace = False) 
## dropping the missing values from a specified column.
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
 ## Dropping all missing values( with false for just overview, not definitive)
df_prods.dropna(inplace = False)
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_prods_clean
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
## DUPLICATES

# %%
## finding duplicates ( exact same values in every column, single duplicates are not a inconsitencies in this data)
df_dups = df_prods_clean[df_prods_clean.duplicated()]
### this code creates a new subset of df_prods_clean, containing only rows that are duplicates.

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
## Adressing duplicates, now that are identified we need to delete them
## check the current number of rows in df_prods_clean
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
## Creating a dataframe that doesn't include the duplicates identified
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %%
df_prods.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %%
## 5 fewer errors

# %%
#### TASK 5 / Orders dataframe
## Cheking for consistency.

# %%
#Step 2 Returning descriptive statistics for numerical values
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_week  order_hour_of_day  days_since_prior_order
# count        3.421083e+06       3.421083e+06            3.214874e+06
# mean         2.776219e+00       1.345202e+01            1.111484e+01
# std          2.046829e+00       4.226088e+00            9.206737e+00
# min          0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %%
## values seem to be in context

# %%
#Step 3 Cheking for mixed-type data
for col in df_ords.columns.tolist():
    weird = (df_ords[[col]].map(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_ords[weird])> 0:
        print(col)

# %%
df_ords.info()
## no mixed-type data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0              int64
#  1   order_id                int64
#  2   user_id                 int64
#  3   order_number            int64
#  4   orders_day_of_week      int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(6)
# memory usage: 182.7 MB

# %%
##Step 5. Running a check for missing values in df_ords dataframe
df_ords.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# user_id                        0
# order_number                   0
# orders_day_of_week             0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
df_ords
# Out:
#          Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0                 0   2539329        1             1                   2
# 1                 1   2398795        1             2                   3
# 2                 2    473747        1             3                   3
# 3                 3   2254736        1             4                   4
# 4                 4    431534        1             5                   4
# ...             ...       ...      ...           ...                 ...
# 3421078     3421078   2266710   206209            10                   5
# 3421079     3421079   1854736   206209            11                   4
# 3421080     3421080    626363   206209            12                   1
# 3421081     3421081   2977660   206209            13                   1
# 3421082     3421082    272231   206209            14                   6
#
#          order_hour_of_day  days_since_prior_order
# ...

# %%
## Creating a dataframe to see the 206209 missing values, containing only those values within the product name column that
##meet the condition
df_nan_2 = df_ords[df_ords['days_since_prior_order'].isnull() == True]

# %%
df_nan_2
# Out:
#          Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0                 0   2539329        1             1                   2
# 11               11   2168274        2             1                   2
# 26               26   1374495        3             1                   1
# 39               39   3343014        4             1                   6
# 45               45   2717275        5             1                   3
# ...             ...       ...      ...           ...                 ...
# 3420930     3420930    969311   206205             1                   4
# 3420934     3420934   3189322   206206             1                   3
# 3421002     3421002   2166133   206207             1                   6
# 3421019     3421019   2227043   206208             1                   1
# 3421069     3421069   3154581   206209             1                   3
#
#          order_hour_of_day  days_since_prior_order
# ...

# %%
## cheking if all the missing values are from first orders. From all rows where days_since_prior_order is missin values (NAN)
## getting the unique values from the order_number column.
df_ords[df_ords['days_since_prior_order'].isnull()]['order_number'].unique()
# Out:
# array([1])

# %%
## Step 6. Every single row with a missing value in days_since_prior_order has a order_number ==1.
## Missing values only happen in the user's first order.
### As the missing values finally mean that is the first order because there are not prior days for it.
### It is not a data quality issue, they are sistematically missing for first_time orders so, we are going to keep them.

# %%
##Step 7. Running a Check for duplicate values.
df_dups_ords = df_ords[df_ords.duplicated()]

# %%
df_dups_ords
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, order_id, user_id, order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order]
# Index: []

# %%
df_dups_ords.shape
# Out:
# (0, 7)

# %%
## There are not duplicates in the df_ords dataframe. No need to adress them.

# %%
## Cheking if Unnamed: 0 column corresponds to an index.
df_ords[['Unnamed: 0', 'order_id']].head(20)
# Out:
#     Unnamed: 0  order_id
# 0            0   2539329
# 1            1   2398795
# 2            2    473747
# 3            3   2254736
# 4            4    431534
# 5            5   3367565
# 6            6    550135
# 7            7   3108588
# 8            8   2295261
# 9            9   2550362
# 10          10   1187899
# 11          11   2168274
# 12          12   1501582
# 13          13   1901567
# 14          14    738281
# 15          15   1673511
# 16          16   1199898
# 17          17   3194192
# 18          18    788338
# 19          19   1718559

# %%
## Column Unnamed:0 Corresponds to an default index, doesnt add an new information.It is safe to drop it.
df_ords_clean= df_ords.drop(columns='Unnamed: 0')

# %%
df_ords_clean
# Out:
#          order_id  user_id  order_number  orders_day_of_week  \
# 0         2539329        1             1                   2
# 1         2398795        1             2                   3
# 2          473747        1             3                   3
# 3         2254736        1             4                   4
# 4          431534        1             5                   4
# ...           ...      ...           ...                 ...
# 3421078   2266710   206209            10                   5
# 3421079   1854736   206209            11                   4
# 3421080    626363   206209            12                   1
# 3421081   2977660   206209            13                   1
# 3421082    272231   206209            14                   6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
##Step 9. Exporting dataframes

#Export the cleaned datafrme for df_prods
df_prods_clean_no_dups.to_csv(os.path.join(path, '02 Data','Prepared Data', 'products_clean.csv'))
df_ords_clean.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_clean.csv'))
